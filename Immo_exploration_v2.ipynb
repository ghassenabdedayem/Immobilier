# %% [markdown]
# # Import des librairies et du dataset

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import time
# del(df)

# %%
del(df)
df = pd.read_csv('C:/Users/Ghassen/Documents/Projects/Immobilier/OpenData_Foncier/valeursfoncieres-2019.txt', 
                 sep = '|', 
                 low_memory=False,
                 parse_dates=[8], 
                 squeeze=True)
df.head()

# %%
start_time = time.time()
df = pd.read_csv('C:/Users/Ghassen/Documents/Projects/Immobilier/OpenData_Foncier/valeursfoncieres-2019.txt', 
                 sep = '|', 
                 low_memory=False,
                 parse_dates=[8], 
                 squeeze=True)
df = df.drop(labels=['Code service CH', 'Reference document', '1 Articles CGI', '2 Articles CGI', 
                     '3 Articles CGI', '4 Articles CGI', '5 Articles CGI'], axis = 1)
df = df.drop(labels=['B/T/Q', 'Code voie', 'Identifiant local'], axis=1)
df = df.drop(labels=['Code commune', 'Prefixe de section', 'Section', 'No plan', 'No Volume'], axis=1)
df = df.rename(columns={'No disposition':'No_disposition', 'Date mutation':'Date_mutation', 'Nature mutation':'Nature_mutation', 
                        'Valeur fonciere':'Valeur_fonciere', 'No voie':'No_voie', 'Type de voie':'Type_de_voie', 'Voie':'Voie', 
                        'Code postal':'Code_postal', 'Commune':'Commune',
                        '1er lot':'1er_lot', 'Surface Carrez du 1er lot':'Surface_Carrez_du_1er_lot',
                        '2eme lot':'2eme_lot', 'Surface Carrez du 2eme lot':'Surface_Carrez_du_2eme_lot',
                        '3eme lot':'3eme_lot', 'Surface Carrez du 3eme lot':'Surface_Carrez_du_3eme_lot',
                        '4eme lot':'4eme_lot', 'Surface Carrez du 4eme lot':'Surface_Carrez_du_4eme_lot',
                        '5eme lot':'5eme_lot', 'Surface Carrez du 5eme lot':'Surface_Carrez_du_5eme_lot',
                        'Nombre de lots':'Nombre_de_lots', 'Code type local':'Code_type_local', 'Type local':'Type_local',
                        'Surface reelle bati':'Surface_reelle_bati', 'Nombre pieces principales':'Nombre_pieces_principales',
                        'Nature culture':'Nature_culture', 'Code departement': 'Code_departement',
                        'Nature culture speciale':'Nature_culture_speciale', 'Surface terrain':'Surface_terrain'})
def str_float(x):
    return float(x.replace(',', '.'))

def str_float_simple(x):
    return float(x)

str_2 = lambda x: str(x).replace(',', '.')

def str_int(x):
    return int(x)
df['Valeur_fonciere'] = df['Valeur_fonciere'].apply(str_2)
df['Valeur_fonciere'] = df['Valeur_fonciere'].apply(str_float)
columns = ['1er_lot', 'Surface_Carrez_du_1er_lot', '2eme_lot', 'Surface_Carrez_du_2eme_lot',
           '3eme_lot', 'Surface_Carrez_du_3eme_lot', '4eme_lot', 'Surface_Carrez_du_4eme_lot', 
           '5eme_lot', 'Surface_Carrez_du_5eme_lot' ]

for col in columns:
    try:
        df[col] = df[col].apply(str_2).apply(str_float)
    except: print(col)
plt.figure(figsize=(12,6))
chart = sns.barplot(x = df.Code_departement, y = df.Valeur_fonciere, 
                    order=df['Code_departement'].value_counts()[:30].index,
                    estimator=sum)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
print("--- %s seconds ---" % (time.time() - start_time))
plt.show()
# Out:
# 1er_lot
# 2eme_lot
# 3eme_lot
# --- 438.8994867801666 seconds ---

# %%
df.columns
# Out:
# Index(['Code service CH', 'Reference document', '1 Articles CGI',
#        '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI',
#        'No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')

# %%
df = df.drop(labels=['Code service CH', 'Reference document', '1 Articles CGI', '2 Articles CGI', 
                     '3 Articles CGI', '4 Articles CGI', '5 Articles CGI'], axis = 1)
df = df.drop(labels=['B/T/Q', 'Code voie', 'Identifiant local'], axis=1)
df = df.drop(labels=['Code commune', 'Prefixe de section', 'Section', 'No plan', 'No Volume'], axis=1)

df.head()
# Out:
#    No disposition Date mutation Nature mutation Valeur fonciere  No voie  \
# 0               1    2019-04-01           Vente        37220,00     26.0
# 1               1    2019-04-01           Vente       185100,00     22.0
# 2               1    2019-04-01           Vente       185100,00     22.0
# 3               1    2019-08-01           Vente       209000,00      3.0
# 4               1    2019-07-01           Vente       134900,00      5.0
#
#   Type de voie             Voie  Code postal                Commune  \
# 0          RUE     DE MONTHOLON       1000.0        BOURG-EN-BRESSE
# 1          RUE  GEN DELESTRAINT       1000.0        BOURG-EN-BRESSE
# 2          RUE  GEN DELESTRAINT       1000.0        BOURG-EN-BRESSE
# 3          RUE   DES CHAMPAGNES       1160.0                  PRIAY
# 4          LOT        LE BIOLAY       1370.0  SAINT-ETIENNE-DU-BOIS
#
#   Code departement  ... 5eme lot Surface Carrez du 5eme lot Nombre de lots  \
# ...

# %%
df = df.rename(columns={'No disposition':'No_disposition', 'Date mutation':'Date_mutation', 'Nature mutation':'Nature_mutation', 
                        'Valeur fonciere':'Valeur_fonciere', 'No voie':'No_voie', 'Type de voie':'Type_de_voie', 'Voie':'Voie', 
                        'Code postal':'Code_postal', 'Commune':'Commune',
                        '1er lot':'1er_lot', 'Surface Carrez du 1er lot':'Surface_Carrez_du_1er_lot',
                        '2eme lot':'2eme_lot', 'Surface Carrez du 2eme lot':'Surface_Carrez_du_2eme_lot',
                        '3eme lot':'3eme_lot', 'Surface Carrez du 3eme lot':'Surface_Carrez_du_3eme_lot',
                        '4eme lot':'4eme_lot', 'Surface Carrez du 4eme lot':'Surface_Carrez_du_4eme_lot',
                        '5eme lot':'5eme_lot', 'Surface Carrez du 5eme lot':'Surface_Carrez_du_5eme_lot',
                        'Nombre de lots':'Nombre_de_lots', 'Code type local':'Code_type_local', 'Type local':'Type_local',
                        'Surface reelle bati':'Surface_reelle_bati', 'Nombre pieces principales':'Nombre_pieces_principales',
                        'Nature culture':'Nature_culture', 'Code departement': 'Code_departement',
                        'Nature culture speciale':'Nature_culture_speciale', 'Surface terrain':'Surface_terrain'})
df.head()
# Out:
#    No_disposition Date_mutation Nature_mutation Valeur_fonciere  No_voie  \
# 0               1    2019-04-01           Vente        37220,00     26.0
# 1               1    2019-04-01           Vente       185100,00     22.0
# 2               1    2019-04-01           Vente       185100,00     22.0
# 3               1    2019-08-01           Vente       209000,00      3.0
# 4               1    2019-07-01           Vente       134900,00      5.0
#
#   Type_de_voie             Voie  Code_postal                Commune  \
# 0          RUE     DE MONTHOLON       1000.0        BOURG-EN-BRESSE
# 1          RUE  GEN DELESTRAINT       1000.0        BOURG-EN-BRESSE
# 2          RUE  GEN DELESTRAINT       1000.0        BOURG-EN-BRESSE
# 3          RUE   DES CHAMPAGNES       1160.0                  PRIAY
# 4          LOT        LE BIOLAY       1370.0  SAINT-ETIENNE-DU-BOIS
#
#   Code_departement  ... 5eme_lot Surface_Carrez_du_5eme_lot Nombre_de_lots  \
# ...

# %%
def str_float(x):
    return float(x.replace(',', '.'))

def str_float_simple(x):
    return float(x)

str_2 = lambda x: str(x).replace(',', '.')

def str_int(x):
    return int(x)

# %%
df['Valeur_fonciere'] = df['Valeur_fonciere'].apply(str_2)
df['Valeur_fonciere'] = df['Valeur_fonciere'].apply(str_float)
df.head()
# Out:
#    No_disposition Date_mutation Nature_mutation  Valeur_fonciere  No_voie  \
# 0               1    2019-04-01           Vente          37220.0     26.0
# 1               1    2019-04-01           Vente         185100.0     22.0
# 2               1    2019-04-01           Vente         185100.0     22.0
# 3               1    2019-08-01           Vente         209000.0      3.0
# 4               1    2019-07-01           Vente         134900.0      5.0
#
#   Type_de_voie             Voie  Code_postal                Commune  \
# 0          RUE     DE MONTHOLON       1000.0        BOURG-EN-BRESSE
# 1          RUE  GEN DELESTRAINT       1000.0        BOURG-EN-BRESSE
# 2          RUE  GEN DELESTRAINT       1000.0        BOURG-EN-BRESSE
# 3          RUE   DES CHAMPAGNES       1160.0                  PRIAY
# 4          LOT        LE BIOLAY       1370.0  SAINT-ETIENNE-DU-BOIS
#
#   Code_departement  ... 5eme_lot Surface_Carrez_du_5eme_lot Nombre_de_lots  \
# ...

# %%
df.sort_values(inplace=True, by='Date_mutation')
df.head()
# Out:
#        No_disposition Date_mutation Nature_mutation  Valeur_fonciere  No_voie  \
# 49618               1    2019-01-01           Vente        5718998.0   5002.0
# 49578               1    2019-01-01           Vente        5718998.0     34.0
# 49579               1    2019-01-01           Vente        5718998.0     24.0
# 49580               1    2019-01-01           Vente        5718998.0     54.0
# 49581               1    2019-01-01           Vente        5718998.0      5.0
#
#       Type_de_voie                 Voie  Code_postal   Commune  \
# 49618          RUE  DE LA CROIX DE VAUX       3260.0  SEUILLET
# 49578          RUE          DU DAUPHINE       3300.0    CUSSET
# 49579          RUE          DU DAUPHINE       3300.0    CUSSET
# 49580           AV       DE PUY BESSEAU       3300.0    CUSSET
# 49581          ALL          DU PERIGORD       3300.0    CUSSET
#
#       Code_departement  ... 5eme_lot Surface_Carrez_du_5eme_lot  \
# ...

# %%
columns = ['1er_lot', 'Surface_Carrez_du_1er_lot', '2eme_lot', 'Surface_Carrez_du_2eme_lot',
           '3eme_lot', 'Surface_Carrez_du_3eme_lot', '4eme_lot', 'Surface_Carrez_du_4eme_lot', 
           '5eme_lot', 'Surface_Carrez_du_5eme_lot' ]

for col in columns:
    try:
        df[col] = df[col].apply(str_2).apply(str_float)
    except: print(col)
df.dtypes
# Out:
# 1er_lot
# 2eme_lot
# 3eme_lot
# No_disposition                         int64
# Date_mutation                 datetime64[ns]
# Nature_mutation                       object
# Valeur_fonciere                      float64
# No_voie                              float64
# Type_de_voie                          object
# Voie                                  object
# Code_postal                          float64
# Commune                               object
# Code_departement                      object
# 1er_lot                               object
# Surface_Carrez_du_1er_lot            float64
# 2eme_lot                              object
# Surface_Carrez_du_2eme_lot           float64
# 3eme_lot                              object
# Surface_Carrez_du_3eme_lot           float64
# 4eme_lot                             float64
# Surface_Carrez_du_4eme_lot           float64
# 5eme_lot                             float64
# Surface_Carrez_du_5eme_lot           float64
# ...

# %%
df.describe()
# Out:
#        No_disposition  Valeur_fonciere       No_voie   Code_postal  \
# count    2.535791e+06     2.506530e+06  1.510153e+06  2.507468e+06
# mean     1.199535e+00     9.715970e+05  7.270275e+02  5.197637e+04
# std      7.401537e+00     7.856914e+06  2.076794e+03  2.730261e+04
# min      1.000000e+00     1.000000e-02  1.000000e+00  1.000000e+03
# 25%      1.000000e+00     6.000000e+04  8.000000e+00  3.123000e+04
# 50%      1.000000e+00     1.490000e+05  2.400000e+01  5.020000e+04
# 75%      1.000000e+00     2.690000e+05  8.700000e+01  7.714400e+04
# max      6.940000e+02     2.086000e+09  9.999000e+03  9.749000e+04
#
#        Surface_Carrez_du_1er_lot  Surface_Carrez_du_2eme_lot  \
# count              221065.000000                54274.000000
# mean                   60.976915                   63.399269
# std                    91.917658                   58.867045
# min                     0.140000                    0.130000
# ...

# %%
df.to_csv('cleaned_valeursfoncieres-2019(1).csv', sep=';', index=True)

# %% [markdown]
# # Exploration

# %%
del(df)

df = pd.read_csv('cleaned_valeursfoncieres-2019(1).csv', 
                 sep=';',
                 parse_dates=[8], 
                 squeeze=True,
                 index_col=0,
                 low_memory=False)
df.describe()
# Out:
#        No_disposition  Valeur_fonciere       No_voie  \
# count    2.535791e+06     2.506530e+06  1.510153e+06
# mean     1.199535e+00     9.715970e+05  7.270275e+02
# std      7.401537e+00     7.856914e+06  2.076794e+03
# min      1.000000e+00     1.000000e-02  1.000000e+00
# 25%      1.000000e+00     6.000000e+04  8.000000e+00
# 50%      1.000000e+00     1.490000e+05  2.400000e+01
# 75%      1.000000e+00     2.690000e+05  8.700000e+01
# max      6.940000e+02     2.086000e+09  9.999000e+03
#
#        Surface_Carrez_du_1er_lot  Surface_Carrez_du_2eme_lot  \
# count              221065.000000                54274.000000
# mean                   60.976915                   63.399269
# std                    91.917658                   58.867045
# min                     0.140000                    0.130000
# 25%                    33.700000                   42.750000
# 50%                    52.900000                   60.600000
# ...

# %%
plt.figure(figsize=(12, 6))
chart = sns.countplot(df.Nature_mutation, order=df['Nature_mutation'].value_counts().index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=30)
plt.show()

# %%
plt.figure(figsize=(12,6))
chart = sns.countplot(df.Nombre_pieces_principales)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
chart = sns.countplot(df.Code_departement, order=df['Code_departement'].value_counts()[:30].index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
chart = sns.barplot(x = df.Code_departement, y = df.Valeur_fonciere, 
                    order=df['Code_departement'].value_counts()[:30].index,
                    estimator=sum)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
chart = sns.barplot(x = df.Code_departement, y = df.Valeur_fonciere, 
                    order=df['Code_departement'].value_counts()[:30].index,
                    estimator=np.max)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
array = (np.array(df.Valeur_fonciere[((df.Valeur_fonciere>50000) & (df.Valeur_fonciere<200000))].dropna()))

plt.boxplot(array)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23fd0a83948>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23fd0a83288>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23fd0a65548>],
#  'medians': [<matplotlib.lines.Line2D at 0x23fd0a79388>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23fd0a61d08>],
#  'means': []}

# %%
array = (np.array(df.Valeur_fonciere[(df.Code_departement=='75')&(df.Valeur_fonciere<1000000)].dropna()))
plt.boxplot(array)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23fb54e9c88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23fb54e3b88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23fbda53f08>],
#  'medians': [<matplotlib.lines.Line2D at 0x23fb54e5948>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23fb54e5f88>],
#  'means': []}

# %%
df['Type_de_voie'].value_counts()[:18]
# Out:
# RUE     862542
# AV      195932
# RTE      72401
# CHE      71983
# BD       67221
# ALL      48966
# IMP      35154
# PL       28781
# RES      19975
# QUAI      7859
# LOT       7045
# GR        7038
# CRS       6550
# SQ        6041
# CITE      4295
# CHEM      4018
# VC        2694
# PAS       2679
# Name: Type_de_voie, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(df.Type_de_voie, order=df['Type_de_voie'].value_counts()[:19].index)
plt.show()

# %% [markdown]
# # Séléction d'une partie des données

# %%
liste_postals = [75] # Paris //et première couronne

df2 = df1[df1['Code postal'] // 1000 == liste_postals[0]]

for i in range(len(liste_postals)-1):
    df3 = df1[df1['Code postal'] // 1000 == liste_postals[i]]
    df2 = pd.concat([df3, df3], axis=0)

df2.head()
# Out:
#          No disposition Date mutation Nature mutation Valeur fonciere  \
# 2514051               1    2019-01-02           Vente      1108972,00
# 2514046               1    2019-01-02           Vente       667000,00
# 2514042               1    2019-01-02           Vente       174290,00
# 2514041               1    2019-01-02           Vente       174290,00
# 2514034               1    2019-01-02           Vente       552000,00
#
#         Type de voie       Voie  Code postal   Commune 1er lot  \
# 2514051          RUE     AMPERE      75017.0  PARIS 17      14
# 2514046          RUE  RENNEQUIN      75017.0  PARIS 17     189
# 2514042          RUE   SAUSSURE      75017.0  PARIS 17      47
# 2514041          RUE   SAUSSURE      75017.0  PARIS 17      35
# 2514034          RUE   CARDINET      75017.0  PARIS 17      20
#
#         Surface Carrez du 1er lot  ... 5eme lot Surface Carrez du 5eme lot  \
# 2514051                       NaN  ...      NaN                        NaN
# ...

# %%
len(df2)
# Out:
# 57700

# %%
df2 = df2[df2['Type local'] == 'Appartement']
len(df2)
# Out:
# 36539

# %%
def str_float(x):
    return float(x.replace(',', '.'))

str_2 = lambda x: str(x).replace(',', '.')

df2['Valeur_fonciere'] = df2['Valeur_fonciere'].map(str_2)
df2['Valeur_fonciere'] = df2['Valeur_fonciere'].map(str_float)
df2.head()
# Out:
#          No_disposition Date_mutation Nature_mutation  Valeur_fonciere  \
# 2514046               1    2019-01-02           Vente         667000.0
# 2514041               1    2019-01-02           Vente         174290.0
# 2514034               1    2019-01-02           Vente         552000.0
# 2514039               1    2019-01-02           Vente         493000.0
# 2514137               1    2019-01-02           Vente          80000.0
#
#         Type_de_voie           Voie  Code_postal   Commune 1er_lot  \
# 2514046          RUE      RENNEQUIN      75017.0  PARIS 17     189
# 2514041          RUE       SAUSSURE      75017.0  PARIS 17      35
# 2514034          RUE       CARDINET      75017.0  PARIS 17      20
# 2514039          RUE     DES MOINES      75017.0  PARIS 17      15
# 2514137          PAS  DU PETIT CERF      75017.0  PARIS 17       3
#
#         Surface_Carrez_du_1er_lot  ... 5eme_lot Surface_Carrez_du_5eme_lot  \
# ...

# %%
df2 = df2.drop(labels=['Nature_culture',	'Nature_culture_speciale',	'Surface_terrain'], axis=1)
df2.head(3)
# Out:
#          No_disposition Date_mutation Nature_mutation  Valeur_fonciere  \
# 2514046               1    2019-01-02           Vente         667000.0
# 2514041               1    2019-01-02           Vente         174290.0
# 2514034               1    2019-01-02           Vente         552000.0
#
#         Type_de_voie       Voie  Code_postal   Commune 1er_lot  \
# 2514046          RUE  RENNEQUIN      75017.0  PARIS 17     189
# 2514041          RUE   SAUSSURE      75017.0  PARIS 17      35
# 2514034          RUE   CARDINET      75017.0  PARIS 17      20
#
#         Surface_Carrez_du_1er_lot  ... Surface_Carrez_du_3eme_lot 4eme_lot  \
# 2514046                     59,67  ...                        NaN      NaN
# 2514041                     18,11  ...                        NaN      NaN
# 2514034                     49,51  ...                        NaN      NaN
#
#         Surface_Carrez_du_4eme_lot 5eme_lot  Surface_Carrez_du_5eme_lot  \
# ...

# %%
plt.figure(figsize=(12, 9))
plt.scatter(df2.Surface_reelle_bati, df2.Valeur_fonciere)
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.boxplot(df2['Valeur_fonciere'])
plt.show()
# Out:
# C:\Users\Ghassen\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# C:\Users\Ghassen\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1316: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\Ghassen\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1323: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\Users\Ghassen\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1331: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\Users\Ghassen\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1332: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],

# %%
df2['Sum_Val_Fonc'] = 0

df2.head()
# Out:
#          No_disposition Date_mutation Nature_mutation  Valeur_fonciere  \
# 2514046               1    2019-01-02           Vente         667000.0
# 2514041               1    2019-01-02           Vente         174290.0
# 2514034               1    2019-01-02           Vente         552000.0
# 2514039               1    2019-01-02           Vente         493000.0
# 2514137               1    2019-01-02           Vente          80000.0
#
#         Type_de_voie           Voie  Code_postal   Commune 1er_lot  \
# 2514046          RUE      RENNEQUIN      75017.0  PARIS 17     189
# 2514041          RUE       SAUSSURE      75017.0  PARIS 17      35
# 2514034          RUE       CARDINET      75017.0  PARIS 17      20
# 2514039          RUE     DES MOINES      75017.0  PARIS 17      15
# 2514137          PAS  DU PETIT CERF      75017.0  PARIS 17       3
#
#         Surface_Carrez_du_1er_lot  ... 4eme_lot Surface_Carrez_du_4eme_lot  \
# ...

# %%
pd.plotting.register_matplotlib_converters()
sns.relplot(x = 'Date_mutation', y = 'Valeur_fonciere', data = df2[df2.Valeur_fonciere>600000], kind = 'line')

# %%
cor = df2.corr()
plt.figure(figsize=(12,7))
# fig, ax = plt.subplot()
sns.heatmap(cor, annot=True, cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df2.Nature_mutation, order=df2['Nature_mutation'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(df2.Type_de_voie, order=df2['Type_de_voie'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(12,6))
chart = sns.countplot(df2.Commune, order=df2['Commune'].value_counts().index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(df2.Nombre_pieces_principales, order=df2['Nombre_pieces_principales'].value_counts().index)
plt.show()

# %%
df2.columns
# Out:
# Index(['No_disposition', 'Date_mutation', 'Nature_mutation', 'Valeur_fonciere',
#        'Type_de_voie', 'Voie', 'Code_postal', 'Commune', '1er_lot',
#        'Surface_Carrez_du_1er_lot', '2eme_lot', 'Surface_Carrez_du_2eme_lot',
#        '3eme_lot', 'Surface_Carrez_du_3eme_lot', '4eme_lot',
#        'Surface_Carrez_du_4eme_lot', '5eme_lot', 'Surface_Carrez_du_5eme_lot',
#        'Nombre_de_lots', 'Code_type_local', 'Type_local',
#        'Surface_reelle_bati', 'Nombre_pieces_principales', 'Sum_Val_Fonc'],
#       dtype='object')

# %%
df_describe = df2.describe()

# %%
df_describe
# Out:
#        No_disposition  Valeur_fonciere   Code_postal     4eme_lot  \
# count    36539.000000     3.647500e+04  36539.000000   949.000000
# mean         1.006404     2.353034e+06  75013.562276   107.200211
# std          0.095107     9.704716e+06      5.113537   314.375622
# min          1.000000     1.000000e+00  75001.000000     2.000000
# 25%          1.000000     2.750000e+05  75010.000000    21.000000
# 50%          1.000000     4.700000e+05  75015.000000    44.000000
# 75%          1.000000     9.120000e+05  75018.000000    78.000000
# max          7.000000     1.683000e+08  75020.000000  4238.000000
#
#           5eme_lot  Nombre_de_lots  Code_type_local  Surface_reelle_bati  \
# count   356.000000    36539.000000          36539.0         36539.000000
# mean    118.952247        1.511891              2.0            53.137907
# std     395.294849        0.933112              0.0            40.653358
# min       2.000000        0.000000              2.0             2.000000
# ...

# %%
type(np.array(df2['Surface_reelle_bati'])[0])
# Out:
# numpy.float64
